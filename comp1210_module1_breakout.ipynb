# %% [markdown]
# <a href="https://colab.research.google.com/github/SIT-COMP-1210/module1-breakout-amanuelwzewdie/blob/main/comp1210_module1_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Instructions**
#
#
# *   Replace "{YourGitHubUser}" with your GitHub username
# *   Run the cell above to clone this .ipynb file to your git repository
#
#
# *   Once you are done completing the assignment below, click on "File" above, from the dropdown select "Save a copy in GitHub"
# *   Edit the commit message to reflect your latest change (e.g "Submitting Breakout Session Assignment")
#
#
# *   Commit your change
#
#
# *   Lastly, go to GitHub Classroom repository to confirm your file submission

# %% [markdown]
# **Practice Problems**

# %% [markdown]
# 1) What is wrong with this code?
#
#
# *   print("Hello World")

# %% [markdown]
# 2. Print all the values below
#
# *   Hello Word
# *   3
# *  2+2

# %%
print("Hello Word")
print(3)
print(2+2)
# Out:
# Hello world

# %% [markdown]
# 3. Write a code that prints:
#
#
#       Hello
#
#       Hello
#
#       Hello

# %%
print("Hello")
print("Hello")
print("Hello")
# Out:
# Hello
# Hello
# Hello

# %% [markdown]
# 4. Then combine it to 1 line:
#
#
# *   HelloHelloHello

# %%
print("Hello"*3)
# Out:
# HelloHelloHello

# %% [markdown]
# 5. What will be printed when you run:
#
#
#
#   *   print("2" + "2")
#   output: 22
#
#   *   print(2 + 2)
#   output: 4
#
#   *   print("A")
#   output: A
#
#   *   print("B")
#   output: B
#
#
#   *   print("A" + "B")
#   output: AB
